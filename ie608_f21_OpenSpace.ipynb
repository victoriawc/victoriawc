# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriawc/victoriawc/blob/main/ie608_f21_OpenSpace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext rpy2.ipython

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# %%R
#
# set.seed(1)
#
# x=runif(10)
# x
# Out:
#  [1] 0.26550866 0.37212390 0.57285336 0.90820779 0.20168193 0.89838968
#  [7] 0.94467527 0.66079779 0.62911404 0.06178627

# %% [markdown]
# #Distributions

# %% [markdown]
# ##Log Normal Distribution (R. Wood)

# %% [markdown]
# ###Properties

# %% [markdown]
# ![Screenshot 2021-09-09 162313.jpg](data:image/jpeg;base64,...)
#
# image from https://slidetodoc.com/probability-distribution-functions-normal-distribution-lognormal-distribution-mean-2/

# %% [markdown]
# ###Code Samples

# %%
# %%R
# #Log normal PDF
# x_dlnorm <- seq(0, 12, by = 0.05)
# y_dlnorm <- dlnorm(x_dlnorm)
# plot(y_dlnorm)

# %%
# %%R
# #Log normal CDF
# x_plnorm <- seq(0, 8, by = 0.01)
# y_plnorm <- plnorm(x_plnorm)
# plot(y_plnorm)

# %%
# %%R
# #Random generation for the log normal distribution
# #set.seed(2021)
# N <- 10000
# y_rlnorm <- rlnorm(N)
# y_rlnorm
# hist(y_rlnorm,
#      breaks = 100,
#      main = "")

# %% [markdown]
# Customers of a very popular restaurant usually have to wait in line for a table. Suppose that the wait time Y (in minutes) for a table follows a lognormal distribution with parameters mu=3.5 and sigma=0.10. Concerned about long wait time, the restaurant owner improves the wait time by expanding the facility and hiring more staff. As a result, the wait time for a table is cut by half. After the restaurant expansion, what is the probability that a customer will have to wait more than 20 minutes for a table?
#
# (Problem from https://probabilityandstatsproblemsolve.wordpress.com/2015/10/25/basic-exercises-for-lognormal-distribution/)

# %%
# %%R
#  #x is equal to 20 minutes. The mean will be the given 3.5 + the log of 0.5 to account for the wait being cut in half.
#  #Standard deviation is equal to 0.10.
#  x = 20
#  dlnorm(x, meanlog = 3.5 + log(0.5, 10), sdlog = 0.1)
# Out:
# [1] 0.02528954

# %% [markdown]
# ## Weibull Distribution (Y. Yue)

# %% [markdown]
# ## Properties

# %% [markdown]
# The most general expression of the Weibull pdf is given by the three-parameter Weibull distribution expression, or:![Screen Shot 2021-09-09 at 7.51.32 PM.png](data:image/png;base64,...)
#
# Equation for 3-parameter Weibull pdf
#
# Where:![Screen Shot 2021-09-09 at 7.52.45 PM.png](data:image/png;base64,...)
#
# Conditions for Weibull pdf
#
# and:
#
# β is the shape parameter, also known as the Weibull slope
#
# η is the scale parameter
#
# γ is the location parameter
#
# reference: https://www.weibull.com/hotwire/issue14/relbasics14.htm

# %% [markdown]
# ##Sample Code

# %%
# %%R
# x_pweibull <- seq(- 5, 30, by = 1)
# y_pweibull <- pweibull(x_pweibull, shape = 0.1)
# plot(y_pweibull)
# x_dweibull <- seq(- 5, 30, by = 1)
# y_dweibull <- dweibull(x_dweibull, shape = 0.1)
# plot(y_dweibull)
# x_qweibull <- seq(0, 1, by = 0.02)
# y_qweibull <- qweibull(x_qweibull, shape = 0.1)
# plot(y_qweibull)
# set.seed(16888)
# N <- 100
# y_rweibull <- rweibull(N, shape = 0.1)
# y_rweibull
# plot(density(y_rweibull),
#      main = "Weibull Distribution in R")

# %% [markdown]
# # Discrete Uniform Distribution (V. Platt)
#
# Information from: https://mathworld.wolfram.com/DiscreteUniformDistribution.html
#
# - has "equally likely" outcomes
# - similar to continuous uniform distribution except there are a finite number of outcomes across the range
# - often used to restrict outcomes to integers (such as rolling a dice or drawing a card)

# %%
# sample code for discrete normal distribution 
# code used from https://www.rdocumentation.org/packages/extraDistr/versions/1.9.1/topics/DiscreteUniform
# %%R 
install.package('extraDistr')
x <- rdunif(10, 1, 10) 
xx <- -1:11
plot(prop.table(table(x)), type = "h")
lines(xx, ddunif(xx, 1, 10), col = "red")
hist(pdunif(x, 1, 10))
xx <- seq(-1, 11, by = 0.01)
plot(ecdf(x))
lines(xx, pdunif(xx, 1, 10), col = "red")
# Out:
# R[write to console]: Error in rdunif(10, 1, 10) : could not find function "rdunif"
# Error in rdunif(10, 1, 10) : could not find function "rdunif"
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
# ...

# %% [markdown]
# ##Bernoulli Distribution (A.Elallam)
#
# A Bernoulli distribution has only two possible outcomes, namely 1 (success) and 0 (failure), and a single trial, for example, a coin toss. So the random variable X which has a Bernoulli distribution can take value 1 with the probability of success, p, and the value 0 with the probability of failure, q or 1−p. The probabilities of success and failure need not be equally likely. The Bernoulli distribution is a special case of the binomial distribution where a single trial is conducted (n=1). Its probability mass function is given by:
#
# $$ f(k,p) = p^{k}(1-p)^{1-k} \hskip2cm for \hskip0.1cm k \in \{0,1\}$$
#
# ### Bernouli in Python
